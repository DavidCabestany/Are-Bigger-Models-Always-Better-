# %% [markdown]
# DATA LOADING

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
TextsDF_Base = []
TextsDF_Distil = []

for i in range(21):
  TextsDF_Base.append(pd.read_csv('/content/drive/MyDrive/Zero_shot_folds_10k/bert-base-uncased_Fold'+str(i)+'.csv'))
  TextsDF_Distil.append(pd.read_csv('/content/drive/MyDrive/Zero_shot_folds_10k/distilbert-base-uncased_Fold'+str(i)+'.csv'))

# %% [markdown]
# CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true_base = []
y_true_distil = []
y_predict_base = []
y_predict_distil = []
for b in range(21):
  y_true_distil.extend(TextsDF_Distil[b]['overall'].to_list())
  y_predict_distil.extend(TextsDF_Distil[b]['result'].to_list())

  y_true_base.extend(TextsDF_Base[b]['overall'].to_list())
  y_predict_base.extend(TextsDF_Base[b]['result'].to_list())

# %%
cm_distil = confusion_matrix(y_true_distil, y_predict_distil, labels=["positive", "negative"])
cm_base = confusion_matrix(y_true_base, y_predict_base, labels=["positive", "negative"])

# %%
print("Confusion matrix for DistilBERT")
print(cm_distil)
print("Confusion matrix for BERT-Base")
print(cm_base)
# Out:
# Confusion matrix for DistilBERT
# [[4846   72]
#  [4462  356]]
# Confusion matrix for BERT-Base
# [[4906   12]
#  [4739   79]]

# %% [markdown]
# ACCURACY

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
precision_recall_fscore_support_MACRO_distil = precision_recall_fscore_support(y_true_distil, y_predict_distil, average='macro')
precision_recall_fscore_support_MACRO_base = precision_recall_fscore_support(y_true_base, y_predict_base, average='macro')

precision_recall_fscore_support_MICRO_distil = precision_recall_fscore_support(y_true_distil, y_predict_distil, average='micro')
precision_recall_fscore_support_MICRO_base = precision_recall_fscore_support(y_true_base, y_predict_base, average='micro')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Precision, recall, F1 MACRO, Support for DistilBERT:")
print(precision_recall_fscore_support_MACRO_distil)

print("Precision, recall, F1 MACRO, Support for BERT-Base:")
print(precision_recall_fscore_support_MACRO_base)

print("Precision, recall, F1 MICRO, Support for DistilBERT:")
print(precision_recall_fscore_support_MICRO_distil)

print("Precision, recall, F1 MICRO, Support for BERT-Base:")
print(precision_recall_fscore_support_MICRO_base)
# Out:
# Precision, recall, F1 MACRO, Support for DistilBERT:
# (0.4508010394033472, 0.3468, 0.26951832812146875, None)
# Precision, recall, F1 MACRO, Support for BERT-Base:
# (0.4589297345129382, 0.3323333333333333, 0.2336749725609588, None)
# Precision, recall, F1 MICRO, Support for DistilBERT:
# (0.5202, 0.5202, 0.5202, None)
# Precision, recall, F1 MICRO, Support for BERT-Base:
# (0.4985, 0.4985, 0.4985, None)

# %% [markdown]
# ACCURACY

# %%
from sklearn.metrics import accuracy_score

# %%
acc_Distil = accuracy_score(y_true_distil, y_predict_distil)
acc_Base = accuracy_score(y_true_base, y_predict_base)

# %%
print("Accuracy for DistilBERT_zero_shot")
print(acc_Distil)
print("Accuracy for BERT-Base_zero_shot")
print(acc_Base)
# Out:
# Accuracy for DistilBERT_zero_shot
# 0.5202
# Accuracy for BERT-Base_zero_shot
# 0.4985
